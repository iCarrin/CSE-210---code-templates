# %%
import pandas as pd
from lets_plot import *
import numpy as np

camp = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bank.csv')
# chom = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bank_holdout_test_mini.csv')

camp.head(50)
# Out:
#     age            job   marital            education  default  housing  \
# 0    56      housemaid   married             basic.4y       no       no
# 1    57       services   married          high.school  unknown       no
# 2    37       services   married          high.school       no      yes
# 3    40         admin.   married             basic.6y       no       no
# 4    56       services   married          high.school       no       no
# 5    45       services   married             basic.9y  unknown       no
# 6    59         admin.   married  professional.course       no       no
# 7    41    blue-collar   married              unknown  unknown       no
# 8    24     technician    single  professional.course       no      yes
# 9    25       services    single          high.school       no      yes
# 10   41    blue-collar   married              unknown  unknown       no
# 11   25       services    single          high.school       no      yes
# 12   57      housemaid  divorced             basic.4y       no      yes
# 13   35    blue-collar   married             basic.6y       no      yes
# 14   54        retired   married             basic.9y  unknown      yes
# 15   50    blue-collar   married             basic.9y       no      yes
# 16   30     unemployed   married          high.school       no       no
# 17   55    blue-collar   married             basic.4y  unknown      yes
# 18   55        retired    single          high.school       no      yes
# 19   41     technician    single          high.school       no      yes
# 20   37         admin.   married          high.school       no      yes
# 21   35     technician   married    university.degree       no       no
# 22   59     technician   married              unknown       no      yes
# 23   39  self-employed   married             basic.9y  unknown       no
# 24   54     technician    single    university.degree  unknown       no
# 25   55        unknown   married    university.degree  unknown  unknown
# 26   46         admin.   married              unknown       no       no
# 27   59     technician   married              unknown       no      yes
# 28   49    blue-collar   married              unknown       no       no
# 29   54     management   married             basic.4y  unknown      yes
# 30   55        unknown   married             basic.4y  unknown      yes
# 31   34       services   married          high.school       no       no
# 32   52     technician   married             basic.9y       no      yes
# 33   41         admin.   married    university.degree       no      yes
# 34   56     technician   married             basic.4y       no      yes
# 35   32   entrepreneur   married          high.school       no      yes
# 36   38         admin.    single  professional.course       no       no
# 37   57         admin.   married    university.degree       no       no
# 38   44         admin.   married    university.degree  unknown      yes
# 39   42     technician    single  professional.course  unknown       no
# 40   40    blue-collar   married             basic.9y       no       no
# 41   35         admin.   married    university.degree       no      yes
# 42   45    blue-collar   married             basic.9y       no      yes
# 43   54         admin.   married          high.school       no       no
# 44   39      housemaid   married             basic.4y       no       no
# 45   60         admin.   married          high.school       no       no
# 46   53         admin.    single  professional.course       no       no
# 47   55    blue-collar   married             basic.4y  unknown       no
# 48   55     technician   married  professional.course  unknown      yes
# 49   50     management   married    university.degree  unknown       no
#
#        loan    contact month day_of_week  campaign  pdays  previous  \
# 0        no  telephone   may         mon         1    999         0
# 1        no  telephone   may         mon         1    999         0
# 2        no  telephone   may         mon         1    999         0
# 3        no  telephone   may         mon         1    999         0
# 4       yes  telephone   may         mon         1    999         0
# 5        no  telephone   may         mon         1    999         0
# 6        no  telephone   may         mon         1    999         0
# 7        no  telephone   may         mon         1    999         0
# 8        no  telephone   may         mon         1    999         0
# 9        no  telephone   may         mon         1    999         0
# 10       no  telephone   may         mon         1    999         0
# 11       no  telephone   may         mon         1    999         0
# 12       no  telephone   may         mon         1    999         0
# 13       no  telephone   may         mon         1    999         0
# 29  nonexistent           1.1          93.994          -36.4      4.857
# 30  nonexistent           1.1          93.994          -36.4      4.857
# 31  nonexistent           1.1          93.994          -36.4      4.857
# 32  nonexistent           1.1          93.994          -36.4      4.857
# 33  nonexistent           1.1          93.994          -36.4      4.857
# 34  nonexistent           1.1          93.994          -36.4      4.857
# 35  nonexistent           1.1          93.994          -36.4      4.857
# 36  nonexistent           1.1          93.994          -36.4      4.857
# 37  nonexistent           1.1          93.994          -36.4      4.857
# 38  nonexistent           1.1          93.994          -36.4      4.857
# 39  nonexistent           1.1          93.994          -36.4      4.857
# 40  nonexistent           1.1          93.994          -36.4      4.857
# 41  nonexistent           1.1          93.994          -36.4      4.857
# 42  nonexistent           1.1          93.994          -36.4      4.857
# 43  nonexistent           1.1          93.994          -36.4      4.857
# 44  nonexistent           1.1          93.994          -36.4      4.857
# 45  nonexistent           1.1          93.994          -36.4      4.857
# 46  nonexistent           1.1          93.994          -36.4      4.857
# 47  nonexistent           1.1          93.994          -36.4      4.857
# 48  nonexistent           1.1          93.994          -36.4      4.857
# 49  nonexistent           1.1          93.994          -36.4      4.857
#
#     nr.employed   y
# 0        5191.0  no
# 1        5191.0  no
# 2        5191.0  no
# 3        5191.0  no
# 4        5191.0  no
# 5        5191.0  no
# 6        5191.0  no
# 7        5191.0  no
# 8        5191.0  no
# 9        5191.0  no
# 10       5191.0  no
# 11       5191.0  no
# 12       5191.0  no
# 13       5191.0  no
# 14       5191.0  no
# 15       5191.0  no
# 16       5191.0  no
# 17       5191.0  no
# 18       5191.0  no
# 19       5191.0  no
# 20       5191.0  no
# 21       5191.0  no
# 22       5191.0  no
# 23       5191.0  no
# 24       5191.0  no
# 25       5191.0  no
# 26       5191.0  no
# 27       5191.0  no
# 28       5191.0  no
# 29       5191.0  no
# 30       5191.0  no
# 31       5191.0  no
# 32       5191.0  no
# 33       5191.0  no
# 34       5191.0  no
# 35       5191.0  no
# 36       5191.0  no
# 37       5191.0  no
# 38       5191.0  no
# 39       5191.0  no
# 40       5191.0  no
# 41       5191.0  no
# 42       5191.0  no
# 43       5191.0  no
# 44       5191.0  no
# 45       5191.0  no
# 46       5191.0  no
# 47       5191.0  no
# 48       5191.0  no
# 49       5191.0  no

# %%
all_to_look_at = ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
       'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
       'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
       'euribor3m', 'nr.employed', 'y']

camp['pdays'] = camp['pdays'].replace(999, np.nan)
camp['poutcome'] = camp['poutcome'].replace('nonexistent', np.nan)
camp['y'] = camp['y'].replace('no',0).replace('yes',1)
camp.rename(columns={'y':'sub2term'}, inplace=True)
# camp.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-8646422c3254> in <cell line: 0>()
#       6 camp['pdays'] = camp['pdays'].replace(999, np.nan)
#       7 camp['poutcome'] = camp['poutcome'].replace('nonexistent', np.nan)
# ----> 8 camp['y'] = camp['y'].replace('no',0).replace('yes',1)
#       9 camp.rename(columns={'y':'sub2term'}, inplace=True)
#      10 # camp.head(5)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'y'

# %%
camp
# Out:
# array(['no', 'yes', 'unknown'], dtype=object)
